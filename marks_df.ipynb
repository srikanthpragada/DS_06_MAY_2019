# %%
import pandas as pd
import numpy as np

# %%
marks = pd.read_csv("marks.csv")

# %%
marks
# Out:
#    Sno     Name  Java  Python  Html  Sql
# 0  101     Bill    80    77.0  90.0   70
# 1  102     Andy    81    78.0  79.0   79
# 2  103    Scott    80    78.0  97.0   78
# 3  104      Joe    81    75.0   NaN   70
# 4  105      Tom    88    77.0  89.0   77
# 5  106    Steve    89     NaN  80.0   60
# 6  107  Roberts    82    78.0  92.0   70
# 7  108      NaN    83    77.0   NaN   56

# %%
marks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
# Sno       8 non-null int64
# Name      7 non-null object
# Java      8 non-null int64
# Python    7 non-null float64
# Html      6 non-null float64
# Sql       8 non-null int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 464.0+ bytes

# %%
## Convert float to int
marks['Python'].fillna(0,inplace=True)
marks['Python'] = marks['Python'].astype('int32')

# %%
marks
# Out:
#    Sno     Name  Java  Python  Html  Sql
# 0  101     Bill    80      77  90.0   70
# 1  102     Andy    81      78  79.0   79
# 2  103    Scott    80      78  97.0   78
# 3  104      Joe    81      75   NaN   70
# 4  105      Tom    88      77  89.0   77
# 5  106    Steve    89       0  80.0   60
# 6  107  Roberts    82      78  92.0   70
# 7  108      NaN    83      77   NaN   56

# %%
marks.to_csv("final_marks.csv",index=False)

# %%
marks.to_json("marks.json", orient='records')

# %%
marks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
# Sno       8 non-null int64
# Name      7 non-null object
# Java      8 non-null int64
# Python    8 non-null int32
# Html      6 non-null float64
# Sql       8 non-null int64
# dtypes: float64(1), int32(1), int64(3), object(1)
# memory usage: 432.0+ bytes

# %%
marks.isna()
# Out:
#      Sno   Name   Java  Python   Html    Sql
# 0  False  False  False   False  False  False
# 1  False  False  False   False  False  False
# 2  False  False  False   False  False  False
# 3  False  False  False   False   True  False
# 4  False  False  False   False  False  False
# 5  False  False  False    True  False  False
# 6  False  False  False   False  False  False
# 7  False   True  False   False   True  False

# %%
marks.isna().any()
# Out:
# Sno       False
# Name       True
# Java      False
# Python     True
# Html       True
# Sql       False
# dtype: bool

# %%
marks.isna().any(axis=1)
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# dtype: bool

# %%
marks.isna().all(axis=1)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
marks.loc[marks.isna().any(axis=1)]
# Out:
#    Sno   Name  Java  Python  Html  Sql
# 3  104    Joe    81    75.0   NaN   70
# 5  106  Steve    89     NaN  80.0   60
# 7  108    NaN    83    77.0   NaN   56

# %%
marks[['Java','Python','Html']].fillna(0)
# Out:
#    Java  Python  Html
# 0    80    77.0  90.0
# 1    81    78.0  79.0
# 2    80    78.0  97.0
# 3    81    75.0   0.0
# 4    88    77.0  89.0
# 5    89     0.0  80.0
# 6    82    78.0  92.0
# 7    83    77.0   0.0

# %%
marks.dropna(axis=1)  # Cols without null values
# Out:
#    Sno  Java  Sql
# 0  101    80   70
# 1  102    81   79
# 2  103    80   78
# 3  104    81   70
# 4  105    88   77
# 5  106    89   60
# 6  107    82   70
# 7  108    83   56

# %%
marks.dropna()  # Rows without null values
# Out:
#    Sno     Name  Java  Python  Html  Sql
# 0  101     Bill    80    77.0  90.0   70
# 1  102     Andy    81    78.0  79.0   79
# 2  103    Scott    80    78.0  97.0   78
# 4  105      Tom    88    77.0  89.0   77
# 6  107  Roberts    82    78.0  92.0   70

# %%
marks.replace([90,89],95)
# Out:
#    Sno     Name  Java  Python  Html  Sql
# 0  101     Bill    80    77.0  95.0   70
# 1  102     Andy    81    78.0  79.0   79
# 2  103    Scott    80    78.0  97.0   78
# 3  104      Joe    81    75.0   NaN   70
# 4  105      Tom    88    77.0  95.0   77
# 5  106    Steve    95     NaN  80.0   60
# 6  107  Roberts    82    78.0  92.0   70
# 7  108      NaN    83    77.0   NaN   56

# %%
marks.replace({'Java' : 89, 'Python' : 90},95)
# Out:
#    Sno     Name  Java  Python  Html  Sql
# 0  101     Bill    80    77.0  90.0   70
# 1  102     Andy    81    78.0  79.0   79
# 2  103    Scott    80    78.0  97.0   78
# 3  104      Joe    81    75.0   NaN   70
# 4  105      Tom    88    77.0  89.0   77
# 5  106    Steve    95     NaN  80.0   60
# 6  107  Roberts    82    78.0  92.0   70
# 7  108      NaN    83    77.0   NaN   56

# %%
marks.head()
# Out:
#    Sno   Name  Java  Python  Html  Sql
# 0  101   Bill    80      77    90   70
# 1  102   Andy    81      78    79   79
# 2  103  Scott    80      78    97   78
# 3  104    Joe    81      75    90   70
# 4  105    Tom    88      77    89   77

# %%
marks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
# Sno       8 non-null int64
# Name      8 non-null object
# Java      8 non-null int64
# Python    8 non-null int64
# Html      8 non-null int64
# Sql       8 non-null int64
# dtypes: int64(5), object(1)
# memory usage: 464.0+ bytes

# %%
marks.describe()[['Java','Python']]
# Out:
#             Java     Python
# count   8.000000   8.000000
# mean   83.000000  78.375000
# std     3.545621   3.622844
# min    80.000000  75.000000
# 25%    80.750000  77.000000
# 50%    81.500000  77.500000
# 75%    84.250000  78.000000
# max    89.000000  87.000000

# %%
marks[['Java','Python']].describe()
# Out:
#             Java     Python
# count   8.000000   8.000000
# mean   83.000000  78.375000
# std     3.545621   3.622844
# min    80.000000  75.000000
# 25%    80.750000  77.000000
# 50%    81.500000  77.500000
# 75%    84.250000  78.000000
# max    89.000000  87.000000

# %%
marks.shape
# Out:
# (8, 6)

# %%
marks.describe(include='all')
# Out:
#               Sno Name       Java     Python       Html      Sql
# count     8.00000    8   8.000000   8.000000   8.000000   8.0000
# unique        NaN    8        NaN        NaN        NaN      NaN
# top           NaN  Tom        NaN        NaN        NaN      NaN
# freq          NaN    1        NaN        NaN        NaN      NaN
# mean    104.50000  NaN  83.000000  78.375000  87.125000  70.0000
# std       2.44949  NaN   3.545621   3.622844   6.642665   8.3666
# min     101.00000  NaN  80.000000  75.000000  79.000000  56.0000
# 25%     102.75000  NaN  80.750000  77.000000  80.000000  67.5000
# 50%     104.50000  NaN  81.500000  77.500000  89.500000  70.0000
# 75%     106.25000  NaN  84.250000  78.000000  90.500000  77.2500
# max     108.00000  NaN  89.000000  87.000000  97.000000  79.0000

# %%
marks['Java']
# Out:
# 0    80
# 1    81
# 2    80
# 3    81
# 4    88
# 5    89
# 6    82
# 7    83
# Name: Java, dtype: int64

# %%
marks.Java
# Out:
# 0    80
# 1    81
# 2    80
# 3    81
# 4    88
# 5    89
# 6    82
# 7    83
# Name: Java, dtype: int64

# %%
marks
# Out:
#    Sno     Name  Java  Python  Html  Sql
# 0  101     Bill    80      77    90   70
# 1  102     Andy    81      78    79   79
# 2  103    Scott    80      78    97   78
# 3  104      Joe    81      75    90   70
# 4  105      Tom    88      77    89   77
# 5  106    Steve    89      87    80   60
# 6  107  Roberts    82      78    92   70
# 7  108     Cook    83      77    80   56

# %%
marks.loc[ :, ['Sno','Python']]
# Out:
#    Sno  Python
# 0  101      77
# 1  102      78
# 2  103      78
# 3  104      75
# 4  105      77
# 5  106      87
# 6  107      78
# 7  108      77

# %%
marks.loc[ [0,2,4] , ['Sno','Python']]
# Out:
#    Sno  Python
# 0  101      77
# 2  103      78
# 4  105      77

# %%
marks.loc[ marks['Java'] > 85, ['Name','Java'] ]
# Out:
#     Name  Java
# 4    Tom    88
# 5  Steve    89

# %%
marks.iloc[:,0:3]
# Out:
#    Sno     Name  Java
# 0  101     Bill    80
# 1  102     Andy    81
# 2  103    Scott    80
# 3  104      Joe    81
# 4  105      Tom    88
# 5  106    Steve    89
# 6  107  Roberts    82
# 7  108     Cook    83

# %%
marks.at[5,'Java']
# Out:
# 89

# %%
marks.iat[5,3]
# Out:
# 87

# %%
marks[marks.isin([80,80,90])]
# Out:
#    Sno Name  Java  Python  Html  Sql
# 0  NaN  NaN  80.0     NaN  90.0  NaN
# 1  NaN  NaN   NaN     NaN   NaN  NaN
# 2  NaN  NaN  80.0     NaN   NaN  NaN
# 3  NaN  NaN   NaN     NaN  90.0  NaN
# 4  NaN  NaN   NaN     NaN   NaN  NaN
# 5  NaN  NaN   NaN     NaN  80.0  NaN
# 6  NaN  NaN   NaN     NaN   NaN  NaN
# 7  NaN  NaN   NaN     NaN  80.0  NaN

# %%
marks.isin([80,80,90])
# Out:
#      Sno   Name   Java  Python   Html    Sql
# 0  False  False   True   False   True  False
# 1  False  False  False   False  False  False
# 2  False  False   True   False  False  False
# 3  False  False  False   False   True  False
# 4  False  False  False   False  False  False
# 5  False  False  False   False   True  False
# 6  False  False  False   False  False  False
# 7  False  False  False   False   True  False

# %%
marks.where( marks > 80)
# Out:
#    Sno     Name  Java  Python  Html  Sql
# 0  101     Bill   NaN     NaN  90.0  NaN
# 1  102     Andy  81.0     NaN   NaN  NaN
# 2  103    Scott   NaN     NaN  97.0  NaN
# 3  104      Joe  81.0     NaN  90.0  NaN
# 4  105      Tom  88.0     NaN  89.0  NaN
# 5  106    Steve  89.0    87.0   NaN  NaN
# 6  107  Roberts  82.0     NaN  92.0  NaN
# 7  108     Cook  83.0     NaN   NaN  NaN

# %%
marks > 80
# Out:
#     Sno  Name   Java  Python   Html    Sql
# 0  True  True  False   False   True  False
# 1  True  True   True   False  False  False
# 2  True  True  False   False   True  False
# 3  True  True   True   False   True  False
# 4  True  True   True   False   True  False
# 5  True  True   True    True  False  False
# 6  True  True   True   False   True  False
# 7  True  True   True   False  False  False

# %%
s1 = marks.loc[0]

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s1
# Out:
# Sno        101
# Name      Bill
# Java        80
# Python      77
# Html        90
# Sql         70
# Name: 0, dtype: object

# %%
(s1.iloc[2:] > 80)
# Out:
# Java      False
# Python    False
# Html       True
# Sql       False
# Name: 0, dtype: bool

# %%
marks.values
# Out:
# array([[101, 'Bill', 80, 77, 90, 70],
#        [102, 'Andy', 81, 78, 79, 79],
#        [103, 'Scott', 80, 78, 97, 78],
#        [104, 'Joe', 81, 75, 90, 70],
#        [105, 'Tom', 88, 77, 89, 77],
#        [106, 'Steve', 89, 87, 80, 60],
#        [107, 'Roberts', 82, 78, 92, 70],
#        [108, 'Cook', 83, 77, 80, 56]], dtype=object)

# %%
for c,v in marks.items():
    print(c, v.values)
# Out:
# Sno [101 102 103 104 105 106 107 108]
# Name ['Bill' 'Andy' 'Scott' 'Joe' 'Tom' 'Steve' 'Roberts' 'Cook']
# Java [80 81 80 81 88 89 82 83]
# Python [77 78 78 75 77 87 78 77]
# Html [90 79 97 90 89 80 92 80]
# Sql [70 79 78 70 77 60 70 56]

# %%
for c,v in marks.iloc[:,2:].items():
    res = v.values > 80
    #   print(res)
    print(c, sum(res), sum( v.values <= 80))
# Out:
# Java 6 2
# Python 1 7
# Html 5 3
# Sql 0 8

# %%
java = marks['Java']
print(java)
# Out:
# 0    80
# 1    81
# 2    80
# 3    81
# 4    88
# 5    89
# 6    82
# 7    83
# Name: Java, dtype: int64

# %%
sum(java > 80)
# Out:
# 6

# %%
res = java > 80

# %%
res
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# Name: Java, dtype: bool

# %%
sum(~res)
# Out:
# 2

# %%
marks.nlargest(3,'Java')
# Out:
#    Sno   Name  Java  Python  Html  Sql
# 5  106  Steve    89      87    80   60
# 4  105    Tom    88      77    89   77
# 7  108   Cook    83      77    80   56

# %%
marks.filter(items=['Java','Python'])
# Out:
#    Java  Python
# 0    80      77
# 1    81      78
# 2    80      78
# 3    81      75
# 4    88      77
# 5    89      87
# 6    82      78
# 7    83      77

# %%
marks.filter(like='a',axis=0)
# Out:
# Empty DataFrame
# Columns: [Sno, Name, Java, Python, Html, Sql]
# Index: []

# %%
java
# Out:
# 0    80
# 1    81
# 2    80
# 3    81
# 4    88
# 5    89
# 6    82
# 7    83
# Name: Java, dtype: int64

# %%
sum(java)
# Out:
# 664

# %%
sum( java > 80)
# Out:
# 6

# %%
marks[['Java','Python']].apply(lambda c : c.mean())
# Out:
# Java      83.000
# Python    78.375
# dtype: float64

# %%
marks[['Java','Python']].apply(lambda c : (c.mean(),c.max(),c.min()))
# Out:
# Java        (83.0, 89, 80)
# Python    (78.375, 87, 75)
# dtype: object

# %%
marks.apply(lambda s : s[['Java','Python','Html','Sql']].sum(), axis=1)
# Out:
# 0    317
# 1    317
# 2    333
# 3    316
# 4    331
# 5    316
# 6    322
# 7    296
# dtype: int64

# %%
marks[['Java','Python']].applymap( lambda m : 'Pass' if m > 80 else 'Fail')
# Out:
#    Java Python
# 0  Fail   Fail
# 1  Pass   Fail
# 2  Fail   Fail
# 3  Pass   Fail
# 4  Pass   Fail
# 5  Pass   Pass
# 6  Pass   Fail
# 7  Pass   Fail

# %%
marks = marks.append({'Sno' : '110','Name' : "Mody", 'Java' : 80,'Python' : 88, 'Html' : 80, 'Sql' : 90},
                     ignore_index=True)

# %%
marks
# Out:
#    Sno     Name  Java  Python  Html  Sql
# 0  101     Bill    80      77    90   70
# 1  102     Andy    81      78    79   79
# 2  103    Scott    80      78    97   78
# 3  104      Joe    81      75    90   70
# 4  105      Tom    88      77    89   77
# 5  106    Steve    89      87    80   60
# 6  107  Roberts    82      78    92   70
# 7  108     Cook    83      77    80   56
# 8  110     Mody    80      88    80   90

# %%
marks.drop([7,8])
# Out:
#    Sno     Name  Java  Python  Html  Sql
# 0  101     Bill    80      77    90   70
# 1  102     Andy    81      78    79   79
# 2  103    Scott    80      78    97   78
# 3  104      Joe    81      75    90   70
# 4  105      Tom    88      77    89   77
# 5  106    Steve    89      87    80   60
# 6  107  Roberts    82      78    92   70

# %%
marks
# Out:
#    Sno     Name  Java  Python  Html  Sql
# 0  101     Bill    80      77    90   70
# 1  102     Andy    81      78    79   79
# 2  103    Scott    80      78    97   78
# 3  104      Joe    81      75    90   70
# 4  105      Tom    88      77    89   77
# 5  106    Steve    89      87    80   60
# 6  107  Roberts    82      78    92   70
# 7  108     Cook    83      77    80   56
# 8  110     Mody    80      88    80   90

# %%
marks.loc[10] = ['111','James',80,90,99,89]

# %%
marks
# Out:
#     Sno     Name  Java  Python  Html  Sql
# 0   101     Bill    80      77    90   70
# 1   102     Andy    81      78    79   79
# 2   103    Scott    80      78    97   78
# 3   104      Joe    81      75    90   70
# 4   105      Tom    88      77    89   77
# 5   106    Steve    89      87    80   60
# 6   107  Roberts    82      78    92   70
# 7   108     Cook    83      77    80   56
# 8   110     Mody    80      88    80   90
# 10  111    James    80      90    99   89

# %%
marks['Passmark'] = 50

# %%
marks
# Out:
#     Sno     Name  Java  Python  Html  Sql  Passmark
# 0   101     Bill    80      77    90   70        50
# 1   102     Andy    81      78    79   79        50
# 2   103    Scott    80      78    97   78        50
# 3   104      Joe    81      75    90   70        50
# 4   105      Tom    88      77    89   77        50
# 5   106    Steve    89      87    80   60        50
# 6   107  Roberts    82      78    92   70        50
# 7   108     Cook    83      77    80   56        50
# 8   110     Mody    80      88    80   90        50
# 10  111    James    80      90    99   89        50

# %%
marks['total'] = marks['Java'] + marks['Python']

# %%
marks
# Out:
#     Sno     Name  Java  Python  Html  Sql  Passmark  total
# 0   101     Bill    80      77    90   70        50    157
# 1   102     Andy    81      78    79   79        50    159
# 2   103    Scott    80      78    97   78        50    158
# 3   104      Joe    81      75    90   70        50    156
# 4   105      Tom    88      77    89   77        50    165
# 5   106    Steve    89      87    80   60        50    176
# 6   107  Roberts    82      78    92   70        50    160
# 7   108     Cook    83      77    80   56        50    160
# 8   110     Mody    80      88    80   90        50    168
# 10  111    James    80      90    99   89        50    170

# %%
marks.drop(['Passmark'],axis=1, inplace=True)

# %%
marks.drop(['total'],axis=1, inplace=True)

# %%
marks2 = pd.DataFrame( [(200,"Tom",90,89,77,89),(201,"Kevin",91,88,78,80)], 
                     columns=['Sno','Name','Java','Python','Html','C'] )

# %%
marks2
# Out:
#    Sno   Name  Java  Python  Html   C
# 0  200    Tom    90      89    77  89
# 1  201  Kevin    91      88    78  80

# %%
all = pd.concat( [marks,marks2], ignore_index=True)
# Out:
# d:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
all
# Out:
#        C  Html  Java     Name  Python  Sno   Sql
# 0    NaN    90    80     Bill      77  101  70.0
# 1    NaN    79    81     Andy      78  102  79.0
# 2    NaN    97    80    Scott      78  103  78.0
# 3    NaN    90    81      Joe      75  104  70.0
# 4    NaN    89    88      Tom      77  105  77.0
# 5    NaN    80    89    Steve      87  106  60.0
# 6    NaN    92    82  Roberts      78  107  70.0
# 7    NaN    80    83     Cook      77  108  56.0
# 8    NaN    80    80     Mody      88  110  90.0
# 9    NaN    99    80    James      90  111  89.0
# 10  89.0    77    90      Tom      89  200   NaN
# 11  80.0    78    91    Kevin      88  201   NaN

# %%
marks
# Out:
#     Sno     Name  Java  Python  Html  Sql
# 0   101     Bill    80      77    90   70
# 1   102     Andy    81      78    79   79
# 2   103    Scott    80      78    97   78
# 3   104      Joe    81      75    90   70
# 4   105      Tom    88      77    89   77
# 5   106    Steve    89      87    80   60
# 6   107  Roberts    82      78    92   70
# 7   108     Cook    83      77    80   56
# 8   110     Mody    80      88    80   90
# 10  111    James    80      90    99   89

# %%
marks2
# Out:
#    Sno   Name  Java  Python  Html  Sql
# 0  200    Tom    90      89    77   89
# 1  201  Kevin    91      88    78   80

# %%
marks
# Out:
#     Sno     Name  Java  Python  Html  Sql
# 0   101     Bill    80      77    90   70
# 1   102     Andy    81      78    79   79
# 2   103    Scott    80      78    97   78
# 3   104      Joe    81      75    90   70
# 4   105      Tom    88      77    89   77
# 5   106    Steve    89      87    80   60
# 6   107  Roberts    82      78    92   70
# 7   108     Cook    83      77    80   56
# 8   110     Mody    80      88    80   90
# 10  111    James    80      90    99   89

# %%
gender = pd.Series( ['m','f','m','m','m'],name= 'Gender')

# %%
gender
# Out:
# 0    m
# 1    f
# 2    m
# 3    m
# 4    m
# Name: Gender, dtype: object

# %%
marks.join(gender)
# Out:
#     Sno     Name  Java  Python  Html  Sql Gender
# 0   101     Bill    80      77    90   70      m
# 1   102     Andy    81      78    79   79      f
# 2   103    Scott    80      78    97   78      m
# 3   104      Joe    81      75    90   70      m
# 4   105      Tom    88      77    89   77      m
# 5   106    Steve    89      87    80   60    NaN
# 6   107  Roberts    82      78    92   70    NaN
# 7   108     Cook    83      77    80   56    NaN
# 8   110     Mody    80      88    80   90    NaN
# 10  111    James    80      90    99   89    NaN

# %%
marks.sort_values(['Name'])
# Out:
#     Sno     Name  Java  Python  Html  Sql
# 1   102     Andy    81      78    79   79
# 0   101     Bill    80      77    90   70
# 7   108     Cook    83      77    80   56
# 10  111    James    80      90    99   89
# 3   104      Joe    81      75    90   70
# 8   110     Mody    80      88    80   90
# 6   107  Roberts    82      78    92   70
# 2   103    Scott    80      78    97   78
# 5   106    Steve    89      87    80   60
# 4   105      Tom    88      77    89   77

# %%
marks.rename(columns =  {'Sno':'Id'})
# Out:
#      Id     Name  Java  Python  Html  Sql
# 0   101     Bill    80      77    90   70
# 1   102     Andy    81      78    79   79
# 2   103    Scott    80      78    97   78
# 3   104      Joe    81      75    90   70
# 4   105      Tom    88      77    89   77
# 5   106    Steve    89      87    80   60
# 6   107  Roberts    82      78    92   70
# 7   108     Cook    83      77    80   56
# 8   110     Mody    80      88    80   90
# 10  111    James    80      90    99   89

# %%
marks.sort_index(axis=1)
# Out:
#     Html  Java     Name  Python  Sno  Sql
# 0     90    80     Bill      77  101   70
# 1     79    81     Andy      78  102   79
# 2     97    80    Scott      78  103   78
# 3     90    81      Joe      75  104   70
# 4     89    88      Tom      77  105   77
# 5     80    89    Steve      87  106   60
# 6     92    82  Roberts      78  107   70
# 7     80    83     Cook      77  108   56
# 8     80    80     Mody      88  110   90
# 10    99    80    James      90  111   89

# %%
marks.set_index('Sno')
# Out:
#         Name  Java  Python  Html  Sql
# Sno
# 101     Bill    80      77    90   70
# 102     Andy    81      78    79   79
# 103    Scott    80      78    97   78
# 104      Joe    81      75    90   70
# 105      Tom    88      77    89   77
# 106    Steve    89      87    80   60
# 107  Roberts    82      78    92   70
# 108     Cook    83      77    80   56
# 110     Mody    80      88    80   90
# 111    James    80      90    99   89

# %%
marks
# Out:
#     Sno     Name  Java  Python  Html  Sql
# 0   101     Bill    80      77    90   70
# 1   102     Andy    81      78    79   79
# 2   103    Scott    80      78    97   78
# 3   104      Joe    81      75    90   70
# 4   105      Tom    88      77    89   77
# 5   106    Steve    89      87    80   60
# 6   107  Roberts    82      78    92   70
# 7   108     Cook    83      77    80   56
# 8   110     Mody    80      88    80   90
# 10  111    James    80      90    99   89

# %% [markdown]
# ## writing

# %%
marks.to_pickle("marks.pkl")

# %%
marks = pd.read_pickle("marks.pkl")

# %%
marks
# Out:
#    Sno     Name  Java  Python  Html  Sql
# 0  101     Bill    80    77.0  90.0   70
# 1  102     Andy    81    78.0  79.0   79
# 2  103    Scott    80    78.0  97.0   78
# 3  104      Joe    81    75.0   NaN   70
# 4  105      Tom    88    77.0  89.0   77
# 5  106    Steve    89     NaN  80.0   60
# 6  107  Roberts    82    78.0  92.0   70
# 7  108      NaN    83    77.0   NaN   56

# %% [markdown]
# ## Binning

# %%
java = marks['Java']

# %%
java
# Out:
# 0    80
# 1    81
# 2    80
# 3    81
# 4    88
# 5    89
# 6    82
# 7    83
# Name: Java, dtype: int64

# %%
pd.cut(java,bins=3,precision=0)
# Out:
# 0    (80.0, 83.0]
# 1    (80.0, 83.0]
# 2    (80.0, 83.0]
# 3    (80.0, 83.0]
# 4    (86.0, 89.0]
# 5    (86.0, 89.0]
# 6    (80.0, 83.0]
# 7    (80.0, 83.0]
# Name: Java, dtype: category
# Categories (3, interval[float64]): [(80.0, 83.0] < (83.0, 86.0] < (86.0, 89.0]]

# %%
pd.cut(java,bins=[0,70,80,100], labels=['Poor','Avg','Ex'])
# Out:
# 0    Avg
# 1     Ex
# 2    Avg
# 3     Ex
# 4     Ex
# 5     Ex
# 6     Ex
# 7     Ex
# Name: Java, dtype: category
# Categories (3, object): [Poor < Avg < Ex]

# %%
pd.qcut(java,4,precision=0)
# Out:
# 0    (79.0, 81.0]
# 1    (81.0, 82.0]
# 2    (79.0, 81.0]
# 3    (81.0, 82.0]
# 4    (84.0, 89.0]
# 5    (84.0, 89.0]
# 6    (82.0, 84.0]
# 7    (82.0, 84.0]
# Name: Java, dtype: category
# Categories (4, interval[float64]): [(79.0, 81.0] < (81.0, 82.0] < (82.0, 84.0] < (84.0, 89.0]]

# %%
java.plot()

# %%
# %matplotlib inline

# %%
marks
# Out:
#    Sno     Name  Java  Python  Html  Sql
# 0  101     Bill    80    77.0  90.0   70
# 1  102     Andy    81    78.0  79.0   79
# 2  103    Scott    80    78.0  97.0   78
# 3  104      Joe    81    75.0   NaN   70
# 4  105      Tom    88    77.0  89.0   77
# 5  106    Steve    89     NaN  80.0   60
# 6  107  Roberts    82    78.0  92.0   70
# 7  108      NaN    83    77.0   NaN   56

# %%
avg = marks[['Java','Python','Html','Sql']].mean(axis=1)

# %%
marks['Sno']
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# 5    106
# 6    107
# 7    108
# Name: Sno, dtype: int64

# %%
marks['avg'] = avg

# %%
marks
# Out:
#    Sno     Name  Java  Python  Html  Sql        avg
# 0  101     Bill    80    77.0  90.0   70  79.250000
# 1  102     Andy    81    78.0  79.0   79  79.250000
# 2  103    Scott    80    78.0  97.0   78  83.250000
# 3  104      Joe    81    75.0   NaN   70  75.333333
# 4  105      Tom    88    77.0  89.0   77  82.750000
# 5  106    Steve    89     NaN  80.0   60  76.333333
# 6  107  Roberts    82    78.0  92.0   70  80.500000
# 7  108      NaN    83    77.0   NaN   56  72.000000

# %%
marks[['Sno','avg']].plot(x='Sno',y='avg',kind='bar',legend=False)

# %%
marks[['Python','Java','Sql']].plot()
